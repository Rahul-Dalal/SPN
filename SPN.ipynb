# %%
#!/bin/python3

import sbox
import pbox
import keygen


def encrypt(plain_text, key, prime, stage):
    print("plain text = ", plain_text)
    e_text_1 = pbox.encrypt(plain_text, prime)
    e_text_2 = sbox.substitute_encrypt(e_text_1, key)
    return e_text_2


def decrypt(plain_text, encrypted_text, key, prime, stage):
    d_text_2 = sbox.substitute_decrypt(encrypted_text, key)
    padding = pbox.padding(plain_text, prime)
    d_text_1 = pbox.decrypt(d_text_2, prime, padding)
    return d_text_1


def main():
    key_list = []
    key = keygen.generate_final_key()
    key_list.append(key[:100])
    key_list.append(key[100:])

    stages = int(input("how many stages? > "))
    for i in range(stages):
        key_list.append(sbox.substitute_encrypt(key_list[i+1], key_list[1]))
#        Encryption of Keys 

    primes = keygen.list_primes(stages)
    print("key = ", key)
#     Encrypted Keys
    print("primes = ", primes)
    print("\n========================================\n")

    plain_text = "Hello, How do you do? I am doing fine, thank you. What about you? I am also doing fine."

    encrypted_text = []
    encrypted_text.append(plain_text)

    print("--- Encryption ---")
    for i in range(stages):
        encrypted_text.append(encrypt(encrypted_text[i], key_list[i+1], primes[i], i+1))
        print(f"encrypted stage {i+1} text = ", encrypted_text[i+1])
        
#         Encryption of Plain Text

    print("\n========================================\n")

    decrypted_text = []
    decrypted_text.insert(0, encrypted_text[-1])
    print("--- Decryption ---")
    print("text to be decypted = ", decrypted_text[0])

    for i in range(stages, 0, -1):
        decrypted_text.insert(0, decrypt(encrypted_text[i-1], encrypted_text[i], key_list[i], primes[i-1], i))
        print(f"decrypted stage {i} text = ", decrypted_text[0])


if __name__ == '__main__':
    main()
# Out:
# how many stages? > 3
# key =  f3'F%T$vIG1Xwq/hackxCDe|M@O:6&l72~=PzSontYA!QbNBr#g_i^]dU
# -p)Eu	.}9j;R4{ Lm+Z0>?sKH\[5V(8yJ<,W"`*bMo(3%lg}eDBUi+'<Ew#G]ZatRd78CKJp[1Xc; 6:4$|
# TY&.I^0u2@A)m{x,S*=`~vOFn\/f_z5VN>Lj!	QPsH"W9k
# primes =  [2, 3, 5]
#
# ========================================
#
# --- Encryption ---
# plain text =  Hello, How do you do? I am doing fine, thank you. What about you? I am also doing fine.
# encrypted stage 1 text =
# jQ3Q3QTfXhn3Q	3N_3V	3Qwxn3\3QXhn3jQfN5z	w_j<
# kf3Q3Q33!fN5z	<WnLT3VWnQWT33!n"3Q	3N_!
# plain text =
# jQ3Q3QTfXhn3Q	3N_3V	3Qwxn3\3QXhn3jQfN5z	w_j<
# kf3Q3Q33!fN5z	<WnLT3VWnQWT33!n"3Q	3N_!
# nbZsKZno{Zs&Zbo<nYS0rnZe@PXnbinj\0?nn{1s\1?ZnYS
# nbZsKZno{Zs&Zbo<nYS0rnZe@PXnbinj\0?
# encrypted stage 3 text =  M$\^JZ^\'$\'juM\\.:<m0'\F;FF\K\\p]'$^'s\s\'\Z'Z';'\$;,j\K\u!#\mj:FJ0F.F\$;'0\I,jm)'Z.#s<
#
# ========================================
#
# --- Decryption ---
# text to be decypted =  M$\^JZ^\'$\'juM\\.:<m0'\F;FF\K\\p]'$^'s\s\'\Z'Z';'\$;,j\K\u!#\mj:FJ0F.F\$;'0\I,jm)'Z.#s<
# nbZsKZno{Zs&Zbo<nYS0rnZe@PXnbinj\0?nn{1s\1?ZnYS
# decrypted stage 2 text =
# jQ3Q3QTfXhn3Q	3N_3V	3Qwxn3\3QXhn3jQfN5z	w_j<
# kf3Q3Q33!fN5z	<WnLT3VWnQWT33!n"3Q	3N_!
# decrypted stage 1 text =  Hello, How do you do? I am doing fine, thank you. What about you? I am also doing fine.
